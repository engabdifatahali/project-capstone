# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
# %matplotlib inline

# %%
# !wget -O WHO-COVID-19-global-table-data.csv  https://covid19.who.int/WHO-COVID-19-global-table-data.csv
# Out:
# --2022-01-14 14:36:23--  https://covid19.who.int/WHO-COVID-19-global-table-data.csv
# Resolving covid19.who.int (covid19.who.int)... 143.204.98.21, 143.204.98.105, 143.204.98.64, ...
# Connecting to covid19.who.int (covid19.who.int)|143.204.98.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18063 (18K) [text/csv]
# Saving to: ‘WHO-COVID-19-global-table-data.csv’
#
# WHO-COVID-19-global 100%[===================>]  17.64K  --.-KB/s    in 0s
#
# 2022-01-14 14:36:23 (87.5 MB/s) - ‘WHO-COVID-19-global-table-data.csv’ saved [18063/18063]

# %%
df = pd.read_csv("WHO-COVID-19-global-table-data.csv")
df.head()
# Out:
#                                      Name  WHO Region  \
# Global                                NaN   315345967
# United States of America         Americas    62126362
# India                     South-East Asia    36317927
# Brazil                           Americas    22629460
# The United Kingdom                 Europe    14862142
#
#                           Cases - cumulative total  \
# Global                                 4045.728837
# United States of America              18769.143000
# India                                  2631.725000
# Brazil                                10646.181000
# The United Kingdom                    21892.793000
#
#                           Cases - cumulative total per 100000 population  \
# Global                                                          18493799
# United States of America                                         5279041
# India                                                            1208641
# ...

# %%
df.tail()
# Out:
#                              Name  WHO Region  Cases - cumulative total  \
# Pitcairn Islands  Western Pacific           0                       0.0
# Saint Helena               Africa           0                       0.0
# Tokelau           Western Pacific           0                       0.0
# Turkmenistan               Europe           0                       0.0
# Tuvalu            Western Pacific           0                       0.0
#
#                   Cases - cumulative total per 100000 population  \
# Pitcairn Islands                                               0
# Saint Helena                                                   0
# Tokelau                                                        0
# Turkmenistan                                                   0
# Tuvalu                                                         0
#
#                   Cases - newly reported in last 7 days  \
# Pitcairn Islands                                    0.0
# ...

# %%
df.describe()
# Out:
#          WHO Region  Cases - cumulative total  \
# count  2.380000e+02                237.000000
# mean   2.649966e+06               7850.245181
# std    2.100418e+07               7884.633386
# min    0.000000e+00                  0.000000
# 25%    1.272575e+04                510.378000
# 50%    1.042975e+05               6020.768000
# 75%    6.695635e+05              12215.271000
# max    3.153460e+08              37402.446000
#
#        Cases - cumulative total per 100000 population  \
# count                                    2.380000e+02
# mean                                     1.554101e+05
# std                                      1.256629e+06
# min                                      0.000000e+00
# 25%                                      6.937500e+02
# 50%                                      3.874000e+03
# 75%                                      2.297100e+04
# max                                      1.849380e+07
#
#        Cases - newly reported in last 7 days  \
# ...

# %%
df.shape
# Out:
# (238, 12)

# %%
cdf =df[[ 'Cases - newly reported in last 7 days', 'Deaths - newly reported in last 24 hours']]
cdf.head()
# Out:
#                           Cases - newly reported in last 7 days  \
# Global                                               237.266063
# United States of America                            1594.864000
# India                                                 87.582000
# Brazil                                               143.782000
# The United Kingdom                                  1512.542000
#
#                           Deaths - newly reported in last 24 hours
# Global                                                         NaN
# United States of America                                       NaN
# India                                                          NaN
# Brazil                                                         NaN
# The United Kingdom                                             NaN

# %%
viz =cdf[['Cases - newly reported in last 7 days', 'Deaths - newly reported in last 24 hours']]
viz.hist()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression 
# %matplotlib inline

# %%
df['Cases - cumulative total'].value_counts().to_frame()
# Out:
#               Cases - cumulative total
# 0.000000                            11
# 11703.801000                         1
# 17556.533000                         1
# 6764.857000                          1
# 7520.456000                          1
# ...                                ...
# 279.639000                           1
# 12944.941000                         1
# 12215.271000                         1
# 16360.750000                         1
# 4045.728837                          1
#
# [227 rows x 1 columns]

# %%
avg_cases_cum_total = df["Cases - cumulative total"].astype("float").mean(axis=0)
print("Average of Cases - cumulative total:", avg_norm_loss)
# Out:
# Average of Cases - cumulative total: 7850.245180745988

# %%
avg_Death_cum_total=df['Deaths - cumulative total'].astype('float').mean(axis=0)
print("Average of Deaths - cumulative total:", avg_bore)
# Out:
# Average of Deaths - cumulative total: 93.89517189060433

# %%
from sklearn.metrics import mean_squared_error

# %%
bins = np.linspace(min(df["Cases - cumulative total"]), max(df["Cases - cumulative total"]), 4)
bins
# Out:
# array([    0.   , 12467.482, 24934.964, 37402.446])

# %%
bins = np.linspace(min(df["Deaths - cumulative total"]), max(df["Deaths - cumulative total"]), 4)
bins
# Out:
# array([  0.        , 205.38433333, 410.76866667, 616.153     ])

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression 
# %matplotlib inline

# %%
# %%capture
! pip install seaborn

# %%
df[['Cases - cumulative total','Deaths - cumulative total','Cases - newly reported in last 7 days','Cases - newly reported in last 24 hours']].head()
# Out:
#                           Cases - cumulative total  Deaths - cumulative total  \
# Global                                 4045.728837                  70.692738
# United States of America              18769.143000                 252.712000
# India                                  2631.725000                  35.147000
# Brazil                                10646.181000                 291.795000
# The United Kingdom                    21892.793000                 222.442000
#
#                           Cases - newly reported in last 7 days  \
# Global                                               237.266063
# United States of America                            1594.864000
# India                                                 87.582000
# Brazil                                               143.782000
# The United Kingdom                                  1512.542000
#
#                           Cases - newly reported in last 24 hours
# ...

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["Deaths - cumulative total"])

# set x/y labels and plot title
plt.pyplot.xlabel("Deaths - cumulative total")
plt.pyplot.ylabel("Cases - cumulative total")
plt.pyplot.title("Cases - newly reported in last 7 days")
# Out:
# Text(0.5, 1.0, 'Cases - newly reported in last 7 days')
